# %%
import pandas as pd

df = pd.read_csv('results/supplier_time.csv')
df
# Out:
#       Supplier Transaction Times
# 0                       215.7503
# 1                       248.7644
# 2                       557.4185
# 3                      1290.0260
# 4                      2220.5520
# ...                          ...
# 5057                    265.1423
# 5058                    281.6757
# 5059                    227.0894
# 5060                    246.8475
# 5061                    247.8696
#
# [5062 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [9, 6]
plt.rcParams["figure.autolayout"] = True

axes = df.plot()
axes.get_legend().remove()
plt.ylabel('Time to Execute (ms)', fontsize = 11)
plt.xlabel('Transactions', fontsize = 11)

plt.savefig('Supplier Transaction Times.pdf')
plt.show()

# %%
df = pd.read_csv('results/client_time.csv')
df
# Out:
#     Client Time
# 0    405.181972
# 1    495.062682
# 2    492.703168
# 3    554.244463
# 4    569.764517
# 5    424.726641
# 6    450.320071
# 7    510.990010
# 8    624.763572
# 9    573.629292
# 10   554.515253
# 11   494.191101
# 12   462.655649
# 13   520.134124
# 14   393.175633
# 15   506.833019
# 16   499.543135
# 17   478.121173
# 18   529.891931
# 19   460.025135
# 20   454.332963
# 21   482.400039
# 22   519.332489
# 23   515.446187
# 24   519.332489
# 25   515.446187

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [9, 3]
plt.rcParams["figure.autolayout"] = True

axes = df.plot()
axes.get_legend().remove()
axes.set_ylim([300, 650])
plt.ylabel('Time to Execute (ms)', fontsize = 11)
plt.xlabel('Hour of Day', fontsize = 11)

plt.savefig('Client Transaction Times.pdf')
plt.show()
